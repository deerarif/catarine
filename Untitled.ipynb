# %%
import pandas as pd
import sqlalchemy

# %%
data = "/home/arif/nnewIcon/MASTER WhatsappAuto Update agustus 2023.xlsx"
x = pd.read_excel(data,sheet_name="STOK",index_col=None)
x.dropna(how='all')
x.drop(x.loc[x['Input']=='SUPERSEDE'].index, inplace=True)
x.drop(x.loc[x['Input']=='DISCONTINUE'].index, inplace=True)
x.drop(x.loc[x['Input']=='SUBSTITUSI'].index, inplace=True)
x.drop(x.loc[x['Input'].isnull()].index, inplace=True)
drop_list = ["Input","Ket","OH",902,900,"HET","STD DUS","Respon"]
x = x.drop(x.columns.difference(drop_list), axis=1)
x.map(str)
# Out:
#              Input                            Ket           OH        902  \
# 1      14721KZY700                      VALVE, EX  14721KZY701        nan
# 2      14711KZY700                      VALVE, IN  14711KZY701        nan
# 3      22535KVB900              WEIGHT SET CLUTCH  22535KWN901        nan
# 4      28230KVB900         GEAR COMP KICK SPINDLE  28230KVB902        nan
# 5      06381GF6300             ROD KIT CONNECTING  06381KEV880        nan
# ...            ...                            ...          ...        ...
# 53269    TABRACKET                        BRACKET    TIDAK ADA  TIDAK ADA
# 53270     ULTRA G4  (D) ULTRA G4 0W30 SLMA 1L IDE    TIDAK ADA  TIDAK ADA
# 53271       UNIHID        HID LIGHT SET,UNIVERSAL    TIDAK ADA  TIDAK ADA
# 53272      W21/5WL    BULB,WEDGE BASE (12V 21/5W)    TIDAK ADA  TIDAK ADA
# 53273      YTX7LBS                      AKI YUASA    TIDAK ADA  TIDAK ADA
#
#              900              HET STD DUS  \
# 1            nan            65000       1
# 2            nan            40000       1
# 3            nan           132000      20
# 4            nan            54000       1
# 5            nan           220000      35
# ...          ...              ...     ...
# 53269  TIDAK ADA              550     nan
# 53270  TIDAK ADA              295     nan
# 53271  TIDAK ADA        2.500.000     nan
# 53272  TIDAK ADA               50     nan
# 53273  TIDAK ADA              625     nan
#
#                                                 Respon
# 1      Sudah *DISCONTINUE*, pake P/N ini : 14721KZY701
# 2      Sudah *DISCONTINUE*, pake P/N ini : 14711KZY701
# 3      Sudah *DISCONTINUE*, pake P/N ini : 22535KWN901
# 4      Sudah *DISCONTINUE*, pake P/N ini : 28230KVB902
# 5      Sudah *DISCONTINUE*, pake P/N ini : 06381KEV880
# ...                                                ...
# 53269                                              nan
# 53270                                              nan
# 53271                                              nan
# 53272                                              nan
# 53273                                              nan
#
# [53258 rows x 8 columns]

# %%
database_username = 'root'
database_password = 'satuduatiga'
database_ip       = '192.168.0.13'
database_name     = 'catarine'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name))
db = database_connection.connect()
db.execute("select * from Barang;")

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1408, in Connection.execute(self, statement, parameters, execution_options)
#    1407 try:
# -> 1408     meth = statement._execute_on_connection
#    1409 except AttributeError as err:
#
# AttributeError: 'str' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 db.execute("select * from Barang;")
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1410, in Connection.execute(self, statement, parameters, execution_options)
#    1408     meth = statement._execute_on_connection
#    1409 except AttributeError as err:
# -> 1410     raise exc.ObjectNotExecutableError(statement) from err
#    1411 else:
#    1412     return meth(
#    1413         self,
#    1414         distilled_parameters,
#    1415         execution_options or NO_OPTIONS,
#    1416     )
#
# ObjectNotExecutableError: Not an executable object: 'select * from Barang;'
